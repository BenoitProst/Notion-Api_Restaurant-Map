# %%
from geopy.geocoders import Nominatim

# %% [markdown]
# > 🚨 Point d'attention
# >
# > Il faut anonymiser les tokens et mot de passe

# %%
# Initialisation
import requests, json
token = 'secret_fWo35AIpqqWzhtSPLWGLRb0pLS0qCdld4iDi8mMXc0l'
databaseID ="e92b477b96bf4d2ca78977179c5a6098"
headers = {
    "Authorization": "Bearer " + token,
    "Content-Type": "application/json",
    "Notion-Version": "2022-02-22"
}

# %%
# Response a Database
def responseDatabase(databaseID,headers):
    readUrl=f"https://api.notion.com/v1/databases/{databaseID}"
    res=requests.request("GET",readUrl,headers=headers)
    print(res.status_code)

# %%
responseDatabase(databaseID,headers)
# Out:
# 200

# %%
def readDatabase(databaseID, headers):
    readUrl = f"https://api.notion.com/v1/databases/{databaseID}/query"
    res = requests.request("POST", readUrl, headers=headers)
    data = res.json()
    print(res.status_code)
    #print(res.text)

    
    with open('./full-properties.json', 'w', encoding='utf8') as f:
        json.dump(data, f, ensure_ascii=False)

    return data

# %%
readDatabase(databaseID, headers)
# Out:
# 200
# {'object': 'list',
#  'results': [{'object': 'page',
#    'id': '2d4683d6-600b-4a26-9445-a7ba43dc3e05',
#    'created_time': '2023-06-07T07:00:00.000Z',
#    'last_edited_time': '2023-06-07T07:01:00.000Z',
#    'created_by': {'object': 'user',
#     'id': '8b07ff01-6b86-45ee-8b57-b87046c1d91f'},
#    'last_edited_by': {'object': 'user',
#     'id': '8b07ff01-6b86-45ee-8b57-b87046c1d91f'},
#    'cover': None,
#    'icon': None,
#    'parent': {'type': 'database_id',
#     'database_id': 'e92b477b-96bf-4d2c-a789-77179c5a6098'},
#    'archived': False,
#    'properties': {'Style': {'id': '%3FJmh',
#      'type': 'multi_select',
#      'multi_select': [{'id': 'c6616e1d-a927-409f-b676-5c4f60a77ccb',
#        'name': 'Bistrot',
#        'color': 'pink'},
#       {'id': 'aed4e484-58cd-4f44-a889-b1ec93f3a385',
#        'name': 'Français',
#        'color': 'green'}]},
#     'Date 1er test': {'id': 'EbVP',
#      'type': 'formula',
#      'formula': {'type': 'date',
# ...

# %% [markdown]
# Comment écrire de manière un json dans un fichier ?

# %%
def GeolocRestaurant(databaseID, headers):
    readUrl = f"https://api.notion.com/v1/databases/{databaseID}/query"
    res = requests.request("POST", readUrl, headers=headers)
    data = res.json()
    print(res.status_code)
    #print(res.text)

    
    with open('./full-properties.json', 'w', encoding='utf8') as f:
        json.dump(data, f, ensure_ascii=False)

    print(len(data['results']))
    
    print(data['results'][0]['properties']['Adresse']['rich_text'][0]['text']['content'])
    
    return data['results'][0]['id']

# %%
GeolocRestaurant(databaseID, headers)
# Out:
# 200
# 25
# 43-45 Rue de Cîteaux, 75012 Paris
# '2d4683d6-600b-4a26-9445-a7ba43dc3e05'

# %%
# récupération de la base Notion

readUrl = f"https://api.notion.com/v1/databases/{databaseID}/query"
res = requests.request("POST", readUrl, headers=headers)
data = res.json()
print(res.status_code)
#print(res.text)

with open('./full-properties.json', 'w', encoding='utf8') as f:
    json.dump(data, f, ensure_ascii=False)
# Out:
# 200

# %%
data['results'][0]['properties']['Adresse']['rich_text'][0]['text']['content']
# Out:
# '43-45 Rue de Cîteaux, 75012 Paris'

# %%
RestaurantAdresse = {'ID':[], "Name" :[], "Adresse" :[], "Lat" :[], "Lon" :[]}
locator = Nominatim(user_agent='myGeocoder')

for i in range(len(data['results'])):
    RestaurantAdresse["ID"].append(data['results'][i]['id'])
    
    RestaurantAdresse["Name"].append(data['results'][i]['id'])
    
    RestaurantAdresse["Adresse"].append(data['results'][i]['properties']['Adresse']['rich_text'][0]['text']['content'])
    
    location = locator.geocode(RestaurantAdresse["Adresse"][i])
    
    RestaurantAdresse["Lat"].append(locator.geocode(location.latitude)
                                    
    RestaurantAdresse["Lon"].append(locator.geocode(location.longitude)

# %%
RestaurantAdresse
# Out:
# {'ID': ['2d4683d6-600b-4a26-9445-a7ba43dc3e05',
#   '09c86136-5a93-4938-a8d5-93f7b53d72c3',
#   '30b53409-1d82-4964-ac2f-bf8659469941',
#   '6b93e492-c08e-43a5-9c44-c23cd909f834',
#   'e3890bc1-1682-4b87-b225-10787260a145',
#   '9840fb26-0a68-466b-904e-057c289a0aa7',
#   'e777890c-2ab1-4a74-add4-5387ab15ad41',
#   '544e776e-ecda-4b62-ba5e-5eec27e34e60',
#   '08802c14-e648-421f-ade0-478391e7c790',
#   'e7d931e6-86f5-43eb-af57-a8af3dce4b52',
#   '53d4ace2-21c2-4313-906b-0e175f3681eb',
#   '2b85c266-9489-4b3f-b99e-723341427a23',
#   'ebec2aca-f50a-4d78-aa19-87bf732dc6e3',
#   '0d885ea9-29e4-422d-9ab5-543bb2300b5b',
#   'bb0941f1-1747-4ce7-8ccf-cabe23efd975',
#   '714b308f-44de-41ad-9107-dc9ee74aeed2',
#   '8979907c-81bf-4bcb-9daf-27339e2ee02e',
#   'c8c25ae2-d731-4056-b42c-e97ee3546da0',
#   'db3049eb-51a6-43d0-961b-07edf0967660',
#   '36e4d8a5-7794-4a07-bca5-dfe416abaf12',
#   '8be11712-549a-4739-b716-d8ec89ddb3fb',
#   '57a6812a-9578-4902-8ce8-c11c77869317',
# ...

# %%
locator = Nominatim(user_agent='myGeocoder')
location = locator.geocode('123 rue du chemin vert, 75011')

# %%
RestaurantAdresse["Adresse"][0]
# Out:
# '43-45 Rue de Cîteaux, 75012 Paris'
